# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
from plotly.figure_factory import create_table

# %%
# Loading Dataset.

df = pd.read_csv("C:/Users/Abhishek/Downloads/Data_CSV_Files/netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Describing the dataset.

df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# Information of Dataset.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Checking NULL values.

df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # We have 6 Columns that have NULL values
#
# - Director: 2634 null values.
# - Cast: 825 null values.
# - Country: 831 null values.
# - Date added: 10 null values.
# - Rating: 4 null values.
# - Duration: 3 null values.

# %%
# Total NULL values that we have.

print('Total null values :', df.isnull().sum().sum())
# Out:
# Total null values : 4307

# %%
# Firstly dealing with (Director) column.

df.director = df.director.fillna("Unknown")

# %%
# Checking "Director" column that is it successfully rectified.

df.director.isnull().sum()
# Out:
# 0

# %%
#  Now we are dealing with (Cast) column.

df.cast = df.cast.fillna("Not Listed")

# %%
# Checking "Cast" column that is it successfully rectified.

df.cast.isnull().sum()
# Out:
# 0

# %%
#  Now we are dealing with (Country) column.

df.country = df.country.fillna("Unknown")

# %%
# Checking "Country" column that is it successfully rectified.

df.country.isnull().sum()
# Out:
# 0

# %%
#  Now we are dealing with (Rating) column Bcos after that we drop date_Added and duration  column bcos we have no valueable data in it.

df.rating = df.rating.fillna("Not Listed")

# %%
# Checking "Country" column that is it successfully rectified.

df.rating.isnull().sum()
# Out:
# 0

# %%
# Now we drop rest NULL value rows.

df.dropna(inplace=True)

# %%
# Again checking that now we have NULL values or not.

df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis: Visualization

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          Unknown
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          Unknown
# 4         s5  TV Show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                            Not Listed  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Top Country producing Content.

df.country.value_counts().head(10)
# Out:
# country
# United States     2809
# India              972
# Unknown            830
# United Kingdom     418
# Japan              244
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
sns.barplot(y = df.country.value_counts().head(10).index,x = df.country.value_counts().head(10).values)
plt.xticks(rotation = 90)
plt.title("Visualising Top 10 Countries producing Content")
plt.figure(figsize=(4,3))

# %%
# Least Countries Producing Content.

df.country.value_counts().tail(10)
# Out:
# country
# Mauritius, South Africa                                            1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan    1
# Canada, Norway                                                     1
# India, United Kingdom, Canada, United States                       1
# Philippines, United States                                         1
# Romania, Bulgaria, Hungary                                         1
# Uruguay, Guatemala                                                 1
# France, Senegal, Belgium                                           1
# Mexico, United States, Spain, Colombia                             1
# United Arab Emirates, Jordan                                       1
# Name: count, dtype: int64

# %%
sns.barplot(y = df.country.value_counts().tail(10).index,x = df.country.value_counts().tail(10).values)
plt.xticks(rotation = 90)
plt.title("Visualising Least 10 Countries producing Content")
plt.figure(figsize=(6,4))

# %%
# Visualising top 5 Countries producing content.

plt.pie(df.country.value_counts().head(),labels=df.country.value_counts().head().index,startangle=90, autopct='%.1f%%')
plt.legend(loc='upper left', title="Country")
plt.title('Visualising content produced by top 5 countries')
plt.show()

# %% [markdown]
# # Rating Analysis

# %%
# Top 10 Rating Analysis.

sns.barplot(y = df.rating.value_counts().head(10).values, x = df.rating.value_counts().head(10).index,
           label = df.rating.value_counts().head(10))
plt.title("Top Rating Analysis ")
plt.xlabel('Rating')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
# Least 10 Rating Analysis.

sns.barplot(x = df.rating.value_counts().tail(10).values, y = df.rating.value_counts().tail(10).index)
plt.title("Least Rating Analysis ")
plt.xlabel('Rating')
plt.ylabel('Counts')
plt.xticks(rotation=90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350.]),
#  [Text(0.0, 0, '0'),
#   Text(50.0, 0, '50'),
#   Text(100.0, 0, '100'),
#   Text(150.0, 0, '150'),
#   Text(200.0, 0, '200'),
#   Text(250.0, 0, '250'),
#   Text(300.0, 0, '300'),
#   Text(350.0, 0, '350')])

# %%
df.type.value_counts()
# Out:
# type
# Movie      6128
# TV Show    2666
# Name: count, dtype: int64

# %%
sns.countplot(x=df.type)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
#  - In Above on countplot chart we saw that most of the users like to watch movie too much..

# %%
# visualising market share of rated audience.

plt.pie(df.rating.value_counts().head(5),labels=df.rating.value_counts().head(5).index,autopct='%1.1f%%')
plt.title('visualising market share of rated audience')
# Out:
# Text(0.5, 1.0, 'visualising market share of rated audience')

# %%
# Analysis of Duration.

sns.barplot(x=df.duration.value_counts().head(10).index,y=df.duration.value_counts().head(10).values)
plt.xticks(rotation=90)
plt.title('Analysis of Duration')
plt.xlabel('Duration')
plt.ylabel('Counts')
plt.figure(figsize=(6,4))
plt.show()

# %%
plt.pie(df[df.country=='United States'].rating.value_counts().head(3), labels= df[df.country=='India'].rating.value_counts().head(3).index , autopct='%.1f%%')
plt.title('Rating Distribution in United States')
plt.legend()

# %%
plt.pie(df[df.country=='India'].rating.value_counts().head(3), labels= df[df.country=='India'].rating.value_counts().head(3).index , autopct='%.1f%%')
plt.title('Rating Distribution in India')
plt.legend()

# %%
# Understanding Data on basis od release year.


plt.figure(figsize=(12,6))
sns.countplot(x='release_year',data=df)
plt.xticks(rotation=90)
plt.title('Cointent Release over the year on Netflix')
plt.xlabel('Release Year')
plt.ylabel('Counts')
plt.show()
